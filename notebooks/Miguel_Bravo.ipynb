# %%
import sys
sys.path.append('/Users/ignasivalles/Oceanography/IEO/projects/POM/pom-cost.github.io/src')
from data_functions import *

import pandas as pd
import hvplot.pandas  # This enables hvplot for pandas DataFrames
import panel as pn
import matplotlib.pyplot as plt

import pandas as pd
import hvplot.pandas  # This enables hvplot for pandas DataFrames
import panel as pn
import holoviews as hv
import glob
import os

# Load the dataset
folder_path = "/Users/ignasivalles/Google Drive/La meva unitat/POM/data/Miguel_Bravo/"
historical_data = "/Users/ignasivalles/Google Drive/La meva unitat/POM/data/muestreoCubo1970_78.xlsx"
csv_files = glob.glob(os.path.join(folder_path, "*.csv"))

all_data = pd.concat([get_data_from_temp_sensors(file) for file in csv_files], ignore_index=True)

# Ensure date format and extract fractional time
all_data['Date'] = pd.to_datetime(all_data['Date'])
all_data['Temperature'] = all_data['Temperature'].round(2)

# === 3. Calculate Fractional Time ===
all_data['fractional_time'] = (
    all_data['Date'].dt.month - 1 + (all_data['Date'].dt.day - 1) / all_data['Date'].dt.days_in_month
)

# Create hvplot for Sardinero
line_plot = all_data.hvplot.line(
    x='Date', y='Temperature',  # 
    title='Sea Temperature - Miguel Bravo',
    xlabel='Time', ylabel='Temperature',
    grid=True, line_width=2, color='blue'
).opts(
    width=400,                 # ✅ Reduced plot width
    height=200,              # ✅ Set minimum width
    tools=['hover'],
    hover_tooltips=[('Date', '@Date{%F}'), ('Temperature', '@Temperature')],  # ✅ Corrected tooltip
    margin=(0, 0, 0, 0)            # ✅ Remove white spaces around the plot
)

scatter_plot = all_data.hvplot.scatter(
    x='Date', y='Temperature',
    color='blue', size=26
)

# Overlay the scatter plot on top of the line plot
data_plot = line_plot * scatter_plot



# Display the plots interactively

#hv.save(magdalena_plot,'/Users/ignasivalles/Oceanography/IEO/projects/POM/pom.github.io/magdalena_plot.html')
hv.save(data_plot,'/Users/ignasivalles/Oceanography/IEO/projects/POM/pom-cost.github.io/miguel_plot.html')

data_plot
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='b4eb759c-ddf4-4a8e-835d-173fcd79da5d'>
#   <div id="d2c5485b-dccb-4a04-acae-050316203394" data-root-id="b4eb759c-ddf4-4a8e-835d-173fcd79da5d" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
data=extract_lat_lon_temp_time(csv_files)
time=data.time.values
temp=data.temp.values
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 data=extract_lat_lon_temp_time(csv_files)
#       2 time=data.time.values
#       3 temp=data.temp.values
#
# File ~/Desktop/Oceanography/IEO/POM/pom-cost.github.io/src/data_functions.py:155, in extract_lat_lon_temp_time(file_path)
#     153 def extract_lat_lon_temp_time(file_path):
#     154     # Read the file
# --> 155     with open(file_path, 'r') as file:
#     156         lines = file.readlines()
#     158     # Extract latitude and longitude from metadata
#
# TypeError: expected str, bytes or os.PathLike object, not list

# %%
hv.save(magdalena_plot,'/Users/ignasivalles/Oceanography/IEO/projects/POM/pom.github.io/magdalena_plot.html')
hv.save(sardinero_plot,'/Users/ignasivalles/Oceanography/IEO/projects/POM/pom.github.io/sardinero_plot.html')
# Out:
# ERROR:bokeh.core.validation.check:E-1022 (MIN_PREFERRED_MAX_WIDTH): Expected min_width <= width <= max_width: figure(id='3c9694ae-af29-4454-a258-16bf494acffd', ...)
# ERROR:bokeh.core.validation.check:E-1022 (MIN_PREFERRED_MAX_WIDTH): Expected min_width <= width <= max_width: figure(id='ea6b2e5e-0219-4681-871c-9bb95dc78cad', ...)

# %%
import pandas as pd
import hvplot.pandas  # This enables hvplot for pandas DataFrames
import panel as pn

# Load the dataset
historical_data = "/Users/ignasivalles/Google Drive/La meva unitat/POM/data/muestreoCubo1970_78.xlsx"
df = pd.read_excel(historical_data, header=0)

# Rename columns for consistency
df = df.rename(columns={
    'año': 'year',
    'mes': 'month',
    'dia': 'day',
    'temperatura agua': 'Temperature'  # ✅ Rename for clarity
})

# Create a new 'Date' column
df['Date'] = pd.to_datetime(df[['year', 'month', 'day']])

# Filter data for Sardinero and Magdalena stations
sardinero = df[df['Numero estacion'] == 'Sardinero']
magdalena = df[df['Numero estacion'] == 'Magdalena']

# Create hvplot for Sardinero
sardinero_plot = sardinero.hvplot.line(
    x='Date', y='Temperature',  # ✅ Updated column name
    title='Sea Temperature - Sardinero',
    xlabel='Year', ylabel='Temperature',
    grid=True, line_width=2, color='blue', label='Sardinero'
).opts(
    width=400,                 # ✅ Reduced plot width
    height=200,              # ✅ Set minimum width
    tools=['hover'],
    hover_tooltips=[('Date', '@Date{%F}'), ('Temperature', '@Temperature')],  # ✅ Corrected tooltip
    margin=(0, 0, 0, 0)            # ✅ Remove white spaces around the plot
)

# Create hvplot for Magdalena
magdalena_plot = magdalena.hvplot.line(
    x='Date', y='Temperature',  # ✅ Updated column name
    title='Sea Temperature - Magdalena',
    xlabel='Year', ylabel='Temperature',
    grid=True, line_width=2, color='orange', label='Magdalena'
).opts(
    width=400,                 # ✅ Reduced plot width
    height=200,                # ✅ Set minimum width
    tools=['hover'],
    hover_tooltips=[('Date', '@Date{%F}'), ('Temperature', '@Temperature')],  # ✅ Corrected tooltip
    margin=(0, 0, 0, 0)            # ✅ Remove white spaces around the plot
)

# Display the plots interactively
pn.extension()
layout = pn.Column(sardinero_plot, magdalena_plot, sizing_mode='stretch_width')  # ✅ Apply sizing_mode here

# ✅ Save each plot as an HTML file without white spaces
pn.panel(sardinero_plot).save("/Users/ignasivalles/Oceanography/IEO/projects/POM/pom.github.io/sardinero_plot.html", embed=True)
pn.panel(magdalena_plot).save("/Users/ignasivalles/Oceanography/IEO/projects/POM/pom.github.io/magdalena_plot.html", embed=True)

layout
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='b5b175cc-2593-48d8-909e-f7e8818b9c5c'>
#   <div id="db3c4f3d-ad6f-4f4c-afae-d51b4f358ee3" data-root-id="b5b175cc-2593-48d8-909e-f7e8818b9c5c" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...
