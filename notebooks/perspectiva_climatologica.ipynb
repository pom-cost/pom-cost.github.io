# %%
## Climatological plot

# %%
import sys
sys.path.append('/Users/ignasivalles/Oceanography/IEO/projects/POM/pom-cost.github.io/src')
from data_functions import *
import pandas as pd
import numpy as np
import glob
import os
from holoviews import opts
from bokeh.models import HoverTool
import matplotlib.pyplot as plt
from holoviews import render
from bokeh.layouts import layout
from bokeh.resources import CDN
from bokeh.embed import file_html
from holoviews import save
hv.extension('bokeh')
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='a2907136-5e50-4143-b001-f24589ab51ab'>
#   <div id="ea6c5237-9501-464b-b63f-90589986e8f6" data-root-id="a2907136-5e50-4143-b001-f24589ab51ab" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
def limit_zoom(plot, element):
    plot.state.x_range.bounds = (0, 12)
    plot.state.y_range.bounds = (10, 25)

hv.opts.defaults(
    hv.opts.Curve(responsive=True),
    hv.opts.Area(responsive=True)
)

historical_data = "/Users/ignasivalles/Google Drive/La meva unitat/POM/data/muestreoCubo1970_78.xlsx"
all_data = '/Users/ignasivalles/Oceanography/IEO/projects/POM/pom-cost.github.io/data/individual_data.csv'
clim_plot=plot_climatological_year(historical_data)
df = pd.read_csv(all_data)
df=df.where(df.Temperature>10)
obs_plot=plot_obs(df)

combined_plot= clim_plot * obs_plot

month_boundaries = np.arange(0,13,1)

month_labels = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec','Jan']

combined_plot.opts(
    title="Climatological year",
    xticks=[(i, label) for i, label in zip(month_boundaries, month_labels)],
    show_grid=True,
    width=500,                 # ✅ Reduced plot width
    height=250, 
    margin=(0, 0, 0, 0),
    xlim=(0, 12),
    ylim=(5, 28),
    hooks=[limit_zoom]
)


# 1. Render your Holoviews object to a Bokeh model
bokeh_obj = render(combined_plot, backend='bokeh')

# 2. Wrap in a responsive layout
responsive_layout = layout([[bokeh_obj]], sizing_mode='stretch_both')

# 3. Generate the HTML
html = file_html(responsive_layout, CDN, "Responsive Climatological Plot")
# Out:
# WARNING:param.OverlayPlot01103: responsive mode could not be enabled because fixed width and height were specified.
# 0      1970-01-03
# 1      1970-01-03
# 2      1970-01-08
# 3      1970-01-08
# 4      1970-01-10
#           ...
# 1254   1977-12-14
# 1255   1977-12-27
# 1256   1977-12-27
# 1257   1978-03-07
# 1258   1978-03-07
# Name: Date, Length: 1259, dtype: datetime64[ns]
# 1259
# 12

# %%
save(combined_plot, "/Users/ignasivalles/Oceanography/IEO/projects/POM/pom-cost.github.io/climatological-year/climatological_plot_mbl.html", resources=CDN)
# Out:
# WARNING:param.OverlayPlot01170: responsive mode could not be enabled because fixed width and height were specified.

# %%
combined_plot
# Out:
# WARNING:param.OverlayPlot01241: responsive mode could not be enabled because fixed width and height were specified.
# :Overlay
#    .Area.IQR_hyphen_minus_based_Range :Area   [x]   (y,y2)
#    .Curve.Median                      :Curve   [x]   (y)
#    .Scatter.I                         :Scatter   [fractional_time]   (Temperature,Temperature_Anomaly,Date)

# %%
hv.save(combined_plot,'/Users/ignasivalles/Oceanography/IEO/projects/POM/pom-cost.github.io/climatological-year/climatological_plot.html',backend='bokeh')

# %%
from bokeh.io.export import export_png
from bokeh.io.export import export_svgs

# Get the actual Bokeh plot object
bokeh_plot = hv.render(combined_plot, backend='bokeh')
bokeh_plot.output_backend = "svg"

# Export to PNG (high-res)
export_svgs(bokeh_plot, filename="/Users/ignasivalles/Oceanography/IEO/projects/POM/pom-cost.github.io/climatologia_plot.svg")
# Out:
# The geckodriver version (0.35.0) detected in PATH at /Users/ignasivalles/miniconda3/envs/POM/bin/geckodriver might not be compatible with the detected firefox version (137.0.1); currently, geckodriver 0.36.0 is recommended for firefox 137.*, so it is advised to delete the driver in PATH and retry
# ['/Users/ignasivalles/Oceanography/IEO/projects/POM/pom-cost.github.io/climatologia_plot.svg']
