# %%
## Climatological plot

# %%
import sys
sys.path.append('/Users/ignasivalles/Oceanography/IEO/projects/POM/pom-cost.github.io/src')
from data_functions import *
import pandas as pd
import numpy as np
import glob
import os
from holoviews import opts
from bokeh.models import HoverTool
import matplotlib.pyplot as plt
hv.extension('bokeh')
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='dead3c83-ae57-4803-bb00-4bc28ced44a3'>
#   <div id="a5d3f17a-77ef-4bb9-9fbc-b732d04befcf" data-root-id="dead3c83-ae57-4803-bb00-4bc28ced44a3" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
historical_data = "/Users/ignasivalles/Google Drive/La meva unitat/POM/data/muestreoCubo1970_78.xlsx"
all_data = '/Users/ignasivalles/Oceanography/IEO/projects/POM/pom.github.io/individual_data.csv'
clim_plot=plot_climatological_year(historical_data)
df = pd.read_csv(all_data)
obs_plot=plot_obs(df)

combined_plot= clim_plot * obs_plot

month_boundaries = np.arange(0,13,1)

month_labels = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec','Jan']

combined_plot.opts(title="Climatological year", xticks=[(i, label) for i, label in zip(month_boundaries, month_labels)],
      show_grid=True, margin=(0, 0, 0, 0) )
# Out:
# 0      1970-01-03
# 1      1970-01-03
# 2      1970-01-08
# 3      1970-01-08
# 4      1970-01-10
#           ...
# 1254   1977-12-14
# 1255   1977-12-27
# 1256   1977-12-27
# 1257   1978-03-07
# 1258   1978-03-07
# Name: Date, Length: 1259, dtype: datetime64[ns]
# 1259
# 12
# :Overlay
#    .Area.IQR_hyphen_minus_based_Range :Area   [x]   (y,y2)
#    .Curve.Median                      :Curve   [x]   (y)
#    .Scatter.I                         :Scatter   [fractional_time]   (Temperature,Temperature_Anomaly,Date)

# %%
hv.save(combined_plot,'/Users/ignasivalles/Oceanography/IEO/projects/POM/pom-cost.github.io/climatological-year/climatological_plot.html',backend='bokeh')
